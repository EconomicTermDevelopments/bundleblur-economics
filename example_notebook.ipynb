# %% [markdown]
# # Bundleblur\n\nPhase 2 notebook walkthrough.

# %%
import pandas as pd\nfrom bundleblur import BundleblurCalculator\n

# %%
df = pd.read_csv("bundleblur_dataset.csv")\ndf.head()\n

# %%
calc = BundleblurCalculator()\nresult = calc.calculate_bundleblur(df)\nresult.head()\n

# %%
result["bundleblur_index"].describe()\n

# %%
result.groupby("bundleblur_band").size()\n

# %%
result["bundleblur_index"].hist(bins=20)\n

# %% [markdown]
# Interpretation: `Bundleblur` index is now ready for stress testing.
